# %%
print('hello, World')

# %%
print('hello, World')
# Out:
# hello, World

# %%
print('hello, World')
# Out:
# hello, World

# %%
100**25
# Out:
# 100000000000000000000000000000000000000000000000000

# %%
100**1256
# Out:
# ...
